# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

# %%
## upload image with cv2.imread method , use default options
file_path = r"D:\0_Desctop_Files\Learning\UTM_Project\Homework\H1\H1.1.jpg"

d1 = cv2.imread( file_path, cv2.IMREAD_COLOR )
# https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/
# https://pythonexamples.org/python-opencv-read-image-cv2-imread/
# https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html

# %%
type(d1)
# Out:
# numpy.ndarray

# %%
## Sim error
# https://github.com/opencv/opencv/issues/16269
file_path_buf = r"D:\0_Desctop_Files\Learning\UTM_Project\Homework\dont_exist.jpg"
buf = cv2.imread( file_path_buf, cv2.IMREAD_COLOR )

# %%
type(buf)
# Out:
# NoneType

# %%
file_path_buf = r"D:\0_Desctop_Files\Learning\UTM_Project\Homework\dont_exist.csv"
pd.read_csv( file_path_buf )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 file_path_buf = r"D:\0_Desctop_Files\Learning\UTM_Project\Homework\dont_exist.csv"
# ----> 2 pd.read_csv( file_path_buf )
#
# File D:\Anaconda\anaconda3\envs\tf\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Anaconda\anaconda3\envs\tf\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
plt.imshow( d1 )
# check https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html, description of 
# imread() method , 
# for explanation why image is blue

# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
# https://www.geeksforgeeks.org/matplotlib-pyplot-imshow-in-python/

# %%
d1.shape
# Out:
# (420, 479, 3)

# %%
d1[1,1]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
image_center = [int(x/2) for x in d1.shape[0:2] ]

# %%
image_center
# Out:
# [210, 239]

# %%
d1[image_center[0],image_center[1]]
# Out:
# array([ 14,  14, 132], dtype=uint8)

# %%
#### upload image with GRAYSCALE format
d2 = cv2.imread( file_path , cv2.IMREAD_GRAYSCALE)
plt.imshow( d2 )

# %%
d2.shape
# Out:
# (420, 479)

# %%
d2[1,]
# Out:
# array([255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 254, 255, 255, 253, 255, 254, 255,
#        252, 255, 255, 255, 255, 255, 252, 255, 252, 255, 255, 254, 255,
#        254, 255, 255, 255, 253, 254, 253, 255, 254, 255, 253, 255, 255,
# ...

# %%
# picture below is result of behaviour of imshow
# https://stackoverflow.com/questions/68036122/cv2-grayscale-has-3-channels-and-a-weird-blueish-yellowish-tint
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

plt.imshow(d2, cmap="gray")

# %%
plt.imshow(d2, cmap="viridis") # each numbers maps to specific color , therefore
 # colormap name used to map scalar data to colors, default is viridis for single channels

# %%
sys.getsizeof( d2 )
# Out:
# 201308

# %%
sys.getsizeof( d1 )
# Out:
# 603684

# %%
######## Apply cv2.cvtColor() method to change color space
# https://www.geeksforgeeks.org/python-opencv-cv2-cvtcolor-method/
# https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html
# https://www.educative.io/answers/what-is-the-cv2cvtcolor-method

# %%
timage = cv2.cvtColor( d1 , cv2.COLOR_BGR2RGB) 
plt.imshow(timage)

# %%
timage[image_center[0],image_center[1]]
# Out:
# array([132,  14,  14], dtype=uint8)

# %%
########## Resize Image
# https://www.geeksforgeeks.org/image-resizing-using-opencv-python/
# https://www.geeksforgeeks.org/opencv-resize-without-interpolation/
# https://pyimagesearch.com/2021/01/20/opencv-resize-image-cv2-resize/
# https://www.analyticsvidhya.com/blog/2019/03/opencv-functions-computer-vision-python/   # includes wider topics, applicable for all methods
d1.shape
# Out:
# (420, 479, 3)

# %%
# INTER_NEAREST – a nearest-neighbor interpolation
# INTER_LINEAR – a bilinear interpolation (used by default)
# INTER_AREA – resampling using pixel area relation. It may be a preferred method for image decimation
# INTER_CUBIC – a bicubic interpolation over 4×4 pixel neighborhood
# Out:
# (420, 479, 3)

# %%
timg= cv2.resize( timage , (250,250) , interpolation = cv2.INTER_NEAREST  )
plt.imshow(timg)

# %%
timg= cv2.resize( timage , (1000,1000) , interpolation = cv2.INTER_CUBIC  )
plt.imshow(timg)

# %%
# https://www.geeksforgeeks.org/python-opencv-cv2-copymakeborder-method/
# https://medium.com/codex/why-padding-is-important-in-convolutional-neural-network-cnn-8cf7e9e38ca8
# https://www.geeksforgeeks.org/cnn-introduction-to-padding/

timage_v2 = cv2.copyMakeBorder(src = timage, 
                               top= 10, 
                               bottom = 50, 
                               left = 50,
                               right = 50, 
                               borderType = cv2.BORDER_CONSTANT,
                               value=[255, 255, 255] )

# %%
# Displaying the image 
plt.imshow(timage_v2)

# %%
## Learning Data Science == learning methods and classes
## Learning methods and classes == Learning Data Science
## check methods arguments
## more pixels = more memory requirements
## seek answers to non standard situation in official documentation
